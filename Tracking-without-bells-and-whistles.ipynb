# %% [markdown]
# <a href="https://colab.research.google.com/github/hardik0/Multi-Object-Tracking-Google-Colab/blob/main/Tracking-without-bells-and-whistles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tracking without bells and whistles
# [**Tracking without bells and whistles**](https://arxiv.org/abs/1903.05625) (Philipp Bergmann, [Tim Meinhardt](https://dvl.in.tum.de/team/meinhardt/), [Laura Leal-Taixe](https://dvl.in.tum.de/team/meinhardt/)). This [branch](https://github.com/phil-bergmann/tracking_wo_bnw) includes an updated version of Tracktor for PyTorch 1.3 with an improved object detector. The original results of the paper were produced with the [`iccv_19`](https://github.com/phil-bergmann/tracking_wo_bnw/tree/iccv_19) branch.
#
# **Original code :** [tracking_wo_bnw](https://github.com/phil-bergmann/tracking_wo_bnw) by [@phil-bergmann](https://github.com/phil-bergmann)
#
# <img src="https://github.com/phil-bergmann/tracking_wo_bnw/raw/master/data/method_vis_standalone.png" width="600px">
#
# ### Citation
# ```
# @InProceedings{tracktor_2019_ICCV,
#   author = {Bergmann, Philipp and Meinhardt, Tim and Leal{-}Taix{\'{e}}, Laura},
#   title = {Tracking Without Bells and Whistles},
#   booktitle = {The IEEE International Conference on Computer Vision (ICCV)},
#   month = {October},
#   year = {2019}}
# ```

# %%
! nvidia-smi
! /usr/local/cuda/bin/nvcc --version

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Installation
# Clone this repository & Install packages

# %%
# %%shell
#
# git clone https://github.com/phil-bergmann/tracking_wo_bnw
# cd tracking_wo_bnw
# pip3 install -r requirements.txt
# pip3 install -e .

# %% [markdown]
# MOTChallenge data:
#
# * Download [MOT17Det](https://motchallenge.net/data/MOT17Det.zip), [MOT16Labels](https://motchallenge.net/data/MOT16Labels.zip), [2DMOT2015](https://motchallenge.net/data/2DMOT2015.zip),[ MOT16-det-dpm-raw](https://motchallenge.net/data/2DMOT2015.zip) and [MOT17Labels](https://motchallenge.net/data/MOT17Labels.zip) and place them in the data folder. As the images are the same for MOT17Det, MOT17 and MOT16 we only need one set of images for all three benchmarks.
# * Unzip all the data by executing:

# %%
# %%shell
#
# wget https://motchallenge.net/data/MOT17Det.zip
# wget https://motchallenge.net/data/MOT16-det-dpm-raw.zip
# wget https://motchallenge.net/data/MOT17Labels.zip
# cd tracking_wo_bnw/data
# pwd
# unzip -q -d MOT17Det ../../MOT17Det.zip
# unzip -q -d MOT16Labels ../../MOT16Labels.zip
# unzip -q -d 2DMOT2015 ../../2DMOT2015.zip
# unzip -q -d MOT16-det-dpm-raw ../../MOT16-det-dpm-raw.zip
# unzip -q -d MOT17Labels ../../MOT17Labels.zip
# #rm -r ../../*.zip

# %% [markdown]
# Download object detector and re-identifiaction Siamese network weights and MOTChallenge result files:
#
# * Download zip file from [here](https://vision.in.tum.de/webshare/u/meinhard/tracking_wo_bnw-output_v2.zip).
# * Extract in output directory.

# %%
# %%shell
#
# wget https://vision.in.tum.de/webshare/u/meinhard/tracking_wo_bnw-output_v2.zip
# cd tracking_wo_bnw
# pwd
# unzip -q ../tracking_wo_bnw-output_v2.zip  # output dir

# %%
# %cd tracking_wo_bnw/
# Out:
# /content/tracking_wo_bnw

# %% [markdown]
# ## Evaluate Tracktor
# In order to configure, organize, log and reproduce our computational experiments we structured our code with the [Sacred](http://sacred.readthedocs.io/en/latest/index.html) framework. For a detailed explanation of the Sacred interface please read its documentation.
#
# 1. Tracktor can be configured by changing the corresponding `experiments/cfgs/tracktor.yaml` config file. The default configuration runs Tracktor++ with the FPN object detector as described in the paper.
#
# 2. The default configuration is `Tracktor++`. Run `Tracktor++` by executing:
#
#   `python experiments/scripts/test_tracktor.py`
#
# 3. The results are logged in the corresponding `output` directory.
#
# For reproducability, we provide the new result metrics of this updated code base on the `MOT17` challenge. It should be noted, that these surpass the original Tracktor results. This is due to the newly trained object detector. This version of Tracktor does not differ conceptually from the original ICCV 2019 version (see branch `iccv_19`). The results on the offical MOTChallenge [webpage](https://motchallenge.net/results/MOT17/) are denoted as the `Tracktor++v2` tracker. The train and test results are:
#
# ```
# ********************* MOT17 TRAIN Results *********************
# IDF1  IDP  IDR| Rcll  Prcn   FAR|   GT  MT   PT   ML|    FP    FN   IDs    FM|  MOTA  MOTP MOTAL
# 65.2 83.8 53.3| 63.1  99.2  0.11| 1638 550  714  374|  1732124291   903  1258|  62.3  89.6  62.6
#
# ********************* MOT17 TEST Results *********************
# IDF1  IDP  IDR| Rcll  Prcn   FAR|   GT  MT   PT   ML|    FP    FN   IDs    FM|  MOTA  MOTP MOTAL
# 55.1 73.6 44.1| 58.3  97.4  0.50| 2355 498 1026  831|  8866235449  1987  3763|  56.3  78.8  56.7
# ```

# %%
! python experiments/scripts/test_tracktor.py
# Out:
# WARNING - test_tracktor - No observers have been added to this run
# INFO - test_tracktor - Running command 'main'
# INFO - test_tracktor - Started
# Configuration (modified, added, typechanged, doc):
#   seed = 453695
#   reid:
#     db_train = 'train'
#     db_val = False
#     desription = 'all'
#     lr_scheduler = True
#     max_epochs = 69
#     module_name = 'reid'
#     name = 'res50-mot17-batch_hard'
#     seed = 12345
#     cnn:
#       output_dim = 128
#     dataloader:
#       K = 4
#       P = 18
#       crop_H = 256
#       crop_W = 128
#       max_per_person = 1000
#       normalize_mean = [0.485, 0.456, 0.406]
#       normalize_std = [0.229, 0.224, 0.225]
#       transform = 'random'
#       vis_threshold = 0.3
#     model_args:
#       loss = 'batch_hard'
#       margin = 0.2
#       prec_at_k = 3
#     solver:
#       optim = 'Adam'
#       optim_args:
#         lr = 0.0003
#         weight_decay = 0.0
#   tracktor:
#     dataset = 'mot17_train_FRCNN17'
#     desription = None
#     frame_split = [0.0, 1.0]
#     interpolate = False
#     module_name = 'MOT17'
#     name = 'Tracktor++'
#     network = 'fpn'
#     obj_detect_model = 'output/faster_rcnn_fpn_training_mot_17/model_epoch_27.model'
#     reid_config = 'output/tracktor/reid/res50-mot17-batch_hard/sacred_config.yaml'
#     reid_weights = 'output/tracktor/reid/res50-mot17-batch_hard/ResNet_iter_25245.pth'
#     seed = 12345
#     write_images = False
#     tracker:
#       detection_nms_thresh = 0.3
#       detection_person_thresh = 0.5
#       do_align = True
#       do_reid = True
#       inactive_patience = 10
#       max_features_num = 10
#       number_of_iterations = 100
#       public_detections = True
#       regression_nms_thresh = 0.6
#       regression_person_thresh = 0.5
#       reid_iou_threshold = 0.2
#       reid_sim_threshold = 2.0
#       termination_eps = 1e-05
#       warp_mode = 'cv2.MOTION_EUCLIDEAN'
#       motion_model:
#         center_only = True
#         enabled = False
#         n_steps = 1
# INFO - main - Initializing object detector.
# INFO - main - Tracking: MOT17-02-FRCNN
# 100% 600/600 [05:39<00:00,  1.77it/s]
# INFO - main - Tracks found: 92
# INFO - main - Runtime for MOT17-02-FRCNN: 339.80 s.
# INFO - main - Writing predictions to: /content/tracking_wo_bnw/output/tracktor/MOT17/Tracktor++
# INFO - main - Tracking: MOT17-04-FRCNN
# 100% 1050/1050 [11:34<00:00,  1.51it/s]
# INFO - main - Tracks found: 81
# INFO - main - Runtime for MOT17-04-FRCNN: 694.17 s.
# INFO - main - Writing predictions to: /content/tracking_wo_bnw/output/tracktor/MOT17/Tracktor++
# INFO - main - Tracking: MOT17-05-FRCNN
# 100% 837/837 [03:26<00:00,  4.05it/s]
# INFO - main - Tracks found: 110
# INFO - main - Runtime for MOT17-05-FRCNN: 206.76 s.
# INFO - main - Writing predictions to: /content/tracking_wo_bnw/output/tracktor/MOT17/Tracktor++
# INFO - main - Tracking: MOT17-09-FRCNN
# 100% 525/525 [05:34<00:00,  1.57it/s]
# INFO - main - Tracks found: 38
# INFO - main - Runtime for MOT17-09-FRCNN: 334.88 s.
# INFO - main - Writing predictions to: /content/tracking_wo_bnw/output/tracktor/MOT17/Tracktor++
# INFO - main - Tracking: MOT17-10-FRCNN
# 100% 654/654 [09:32<00:00,  1.14it/s]
# INFO - main - Tracks found: 98
# INFO - main - Runtime for MOT17-10-FRCNN: 572.44 s.
# INFO - main - Writing predictions to: /content/tracking_wo_bnw/output/tracktor/MOT17/Tracktor++
# INFO - main - Tracking: MOT17-11-FRCNN
# 100% 900/900 [13:00<00:00,  1.15it/s]
# INFO - main - Tracks found: 74
# INFO - main - Runtime for MOT17-11-FRCNN: 780.82 s.
# INFO - main - Writing predictions to: /content/tracking_wo_bnw/output/tracktor/MOT17/Tracktor++
# INFO - main - Tracking: MOT17-13-FRCNN
# 100% 750/750 [14:40<00:00,  1.17s/it]
# INFO - main - Tracks found: 134
# INFO - main - Runtime for MOT17-13-FRCNN: 880.44 s.
# INFO - main - Writing predictions to: /content/tracking_wo_bnw/output/tracktor/MOT17/Tracktor++
# INFO - main - Tracking runtime for all sequences (without evaluation or image writing): 3809.31 s for 5316 frames (1.40 Hz)
# /usr/local/lib/python3.6/dist-packages/motmetrics/mot.py:243: FutureWarning: the 'labels' keyword is deprecated, use 'codes' instead
#   idx = pd.MultiIndex(levels=[[],[]], labels=[[],[]], names=['FrameId','Event'])
#                 IDF1   IDP   IDR  Rcll  Prcn  GT  MT  PT  ML  FP    FN IDs   FM  MOTA  MOTP
# MOT17-02-FRCNN 45.9% 78.5% 32.4% 41.2% 99.8%  62   8  32  22  18 10926  57   65 40.8% 0.079
# MOT17-04-FRCNN 71.2% 90.5% 58.7% 64.7% 99.8%  83  32  29  22  67 16775  21   28 64.5% 0.096
# MOT17-05-FRCNN 63.9% 86.7% 50.6% 57.4% 98.3% 133  32  65  36  69  2948  38   60 55.8% 0.143
# MOT17-09-FRCNN 53.6% 68.2% 44.2% 64.2% 99.0%  26  11  13   2  33  1907  23   31 63.1% 0.087
# MOT17-10-FRCNN 65.3% 76.8% 56.8% 72.4% 97.9%  57  28  26   3 202  3546  67  119 70.3% 0.146
# MOT17-11-FRCNN 63.3% 77.0% 53.7% 69.0% 99.0%  75  24  33  18  67  2923  26   25 68.0% 0.082
# MOT17-13-FRCNN 72.7% 84.0% 64.1% 74.2% 97.3% 110  59  40  11 238  3006  60   84 71.6% 0.131
# OVERALL        65.0% 84.0% 53.1% 62.6% 99.0% 546 194 238 114 694 42031 292  412 61.7% 0.106
# INFO - test_tracktor - Completed after 1:10:29

# %% [markdown]
# ## Train and test object detector (Faster-RCNN with FPN) [<img src="https://colab.research.google.com/assets/colab-badge.svg" align="center">](https://colab.research.google.com/github/hardik0/Multi-Object-Tracking-Google-Colab/blob/main/utils/faster_rcnn_fpn_training_mot_17.ipynb)
# For the object detector we followed the new native torchvision implementations of Faster-RCNN with FPN which are pretrained on COCO. The provided object detection model was trained and tested with this Google Colab notebook. The `MOT17Det` train and test results are:
#
# ```
# ********************* MOT17Det TRAIN Results ***********
# Average Precision: 0.9090
# Rcll  Prcn|  FAR     GT     TP     FP     FN| MODA  MODP
# 97.9  93.8| 0.81  66393  64989   4330   1404| 91.4  87.4
#
# ********************* MOT17Det TEST Results ***********
# Average Precision: 0.8150
# Rcll  Prcn|  FAR     GT     TP     FP     FN| MODA  MODP
# 86.5  88.3| 2.23 114564  99132  13184  15432| 75.0  78.3
# ```

# %% [markdown]
# ## Training the reidentifaction model
# 1. The training config file is located at `experiments/cfgs/reid.yaml`.
# 2. Start training by executing:
#
#   `python experiments/scripts/train_reid.py`

# %%
! python experiments/scripts/train_reid.py
# Out:
# WARNING - train_reid - No observers have been added to this run
# INFO - train_reid - Running command 'my_main'
# INFO - train_reid - Started
# {'reid': {'name': 'test', 'module_name': 'reid', 'desription': None, 'seed': 12345, 'db_train': 'mot_reid_small_train', 'db_val': False, 'model_args': {'loss': 'batch_hard', 'margin': 0.2, 'prec_at_k': 3}, 'solver': {'optim': 'Adam', 'optim_args': {'lr': 0.0003, 'weight_decay': 0.0}}, 'dataloader': {'vis_threshold': 0.3, 'P': 18, 'K': 4, 'max_per_person': 1000, 'crop_H': 256, 'crop_W': 128, 'transform': 'random', 'normalize_mean': [0.485, 0.456, 0.406], 'normalize_std': [0.229, 0.224, 0.225]}, 'cnn': {'output_dim': 128}}, 'seed': 97319404}
# [*] Initializing Dataloader
# [*] Loaded 50 persons from sequence MOT17-02.
# [*] Loaded 79 persons from sequence MOT17-04.
# [*] Loaded 112 persons from sequence MOT17-05.
# [*] Loaded 25 persons from sequence MOT17-09.
# [*] Loaded 57 persons from sequence MOT17-10.
# [*] Loaded 68 persons from sequence MOT17-11.
# [*] Loaded 104 persons from sequence MOT17-13.
# [*] Building CNN
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/checkpoints/resnet50-19c8e357.pth
# 100% 97.8M/97.8M [00:00<00:00, 214MB/s]
# [*] Solving ...
# START TRAIN.
# [Iteration 100/25137] 0.569 s/it
# prec_at_k: 0.000
# total_loss: 0.448
# [Iteration 200/25137] 0.593 s/it
# prec_at_k: 0.000
# total_loss: 0.225
# [Iteration 300/25137] 0.596 s/it
# prec_at_k: 0.000
# total_loss: 0.155
# Wrote snapshot to: /content/tracking_wo_bnw/output/tracktor/reid/test/ResNet_iter_399.pth
# [*] New learning rate(s): [0.0003]
# [Iteration 499/25137] 0.597 s/it
# prec_at_k: 0.010
# total_loss: 0.109
# [Iteration 599/25137] 0.597 s/it
# prec_at_k: 0.010
# total_loss: 0.098
# [Iteration 699/25137] 0.599 s/it
# prec_at_k: 0.020
# total_loss: 0.096
# Wrote snapshot to: /content/tracking_wo_bnw/output/tracktor/reid/test/ResNet_iter_798.pth
# [*] New learning rate(s): [0.0003]
# [Iteration 898/25137] 0.598 s/it
# prec_at_k: 0.000
# total_loss: 0.103
# [Iteration 998/25137] 0.598 s/it
# prec_at_k: 0.020
# total_loss: 0.083
# [Iteration 1098/25137] 0.598 s/it
# prec_at_k: 0.020
# total_loss: 0.072
# Wrote snapshot to: /content/tracking_wo_bnw/output/tracktor/reid/test/ResNet_iter_1197.pth
# [*] New learning rate(s): [0.0003]
# [Iteration 1297/25137] 0.598 s/it
# prec_at_k: 0.040
# total_loss: 0.062
# [Iteration 1397/25137] 0.598 s/it
# prec_at_k: 0.080
# total_loss: 0.044
# [Iteration 1497/25137] 0.599 s/it
# prec_at_k: 0.070
# total_loss: 0.054
# Wrote snapshot to: /content/tracking_wo_bnw/output/tracktor/reid/test/ResNet_iter_1596.pth
# [*] New learning rate(s): [0.0003]
# [Iteration 1696/25137] 0.599 s/it
# prec_at_k: 0.010
# total_loss: 0.082
# [Iteration 1796/25137] 0.598 s/it
# prec_at_k: 0.020
# total_loss: 0.077
# [Iteration 1896/25137] 0.597 s/it
# prec_at_k: 0.010
# total_loss: 0.071
# Wrote snapshot to: /content/tracking_wo_bnw/output/tracktor/reid/test/ResNet_iter_1995.pth
# [*] New learning rate(s): [0.0003]
# [Iteration 2095/25137] 0.598 s/it
# prec_at_k: 0.060
# total_loss: 0.054
# [Iteration 2195/25137] 0.598 s/it
# prec_at_k: 0.010
# total_loss: 0.069
# [Iteration 2295/25137] 0.598 s/it
# prec_at_k: 0.010
# total_loss: 0.081
# Wrote snapshot to: /content/tracking_wo_bnw/output/tracktor/reid/test/ResNet_iter_2394.pth
# [*] New learning rate(s): [0.0003]
# [Iteration 2494/25137] 0.599 s/it
# prec_at_k: 0.050
# total_loss: 0.048
# [Iteration 2594/25137] 0.596 s/it
# prec_at_k: 0.050
# total_loss: 0.052
# [Iteration 2694/25137] 0.597 s/it
# prec_at_k: 0.110
# total_loss: 0.053
# Wrote snapshot to: /content/tracking_wo_bnw/output/tracktor/reid/test/ResNet_iter_2793.pth
# [*] New learning rate(s): [0.0003]
# [Iteration 2893/25137] 0.597 s/it
# prec_at_k: 0.090
# total_loss: 0.045
# [Iteration 2993/25137] 0.596 s/it
# prec_at_k: 0.060
# total_loss: 0.049
# [Iteration 3093/25137] 0.596 s/it
# prec_at_k: 0.020
# total_loss: 0.057
# Wrote snapshot to: /content/tracking_wo_bnw/output/tracktor/reid/test/ResNet_iter_3192.pth
# [*] New learning rate(s): [0.0003]
# [Iteration 3292/25137] 0.596 s/it
# prec_at_k: 0.060
# total_loss: 0.060
# [Iteration 3392/25137] 0.596 s/it
# prec_at_k: 0.080
# total_loss: 0.063
# [Iteration 3492/25137] 0.598 s/it
# prec_at_k: 0.070
# total_loss: 0.048
# Wrote snapshot to: /content/tracking_wo_bnw/output/tracktor/reid/test/ResNet_iter_3591.pth
# [*] New learning rate(s): [0.0003]
# [Iteration 3691/25137] 0.599 s/it
# prec_at_k: 0.100
# total_loss: 0.036
# [Iteration 3791/25137] 0.598 s/it
# prec_at_k: 0.120
# total_loss: 0.040
# [Iteration 3891/25137] 0.598 s/it
# prec_at_k: 0.040
# total_loss: 0.038
# Wrote snapshot to: /content/tracking_wo_bnw/output/tracktor/reid/test/ResNet_iter_3990.pth
# [*] New learning rate(s): [0.0003]
# [Iteration
pth
# [*] New learning rate(s): [0.0003]
# [Iteration 8479/25137] 0.594 s/it
# prec_at_k: 0.170
# total_loss: 0.027
# [Iteration 8579/25137] 0.593 s/it
# prec_at_k: 0.220
# total_loss: 0.030
# [Iteration 8679/25137] 0.593 s/it
# prec_at_k: 0.270
# total_loss: 0.029
# Wrote snapshot to: /content/tracking_wo_bnw/output/tracktor/reid/test/ResNet_iter_8778.pth
# [*] New learning rate(s): [0.0003]
# [Iteration 8878/25137] 0.595 s/it
# prec_at_k: 0.250
# total_loss: 0.027
# [Iteration 8978/25137] 0.595 s/it
# prec_at_k: 0.300
# total_loss: 0.021
# [Iteration 9078/25137] 0.594 s/it
# prec_at_k: 0.210
# total_loss: 0.034
# Wrote snapshot to: /content/tracking_wo_bnw/output/tracktor/reid/test/ResNet_iter_9177.pth
# [*] New learning rate(s): [0.0003]
# [Iteration 9277/25137] 0.596 s/it
# prec_at_k: 0.210
# total_loss: 0.027
# [Iteration 9377/25137] 0.594 s/it
# prec_at_k: 0.280
# total_loss: 0.026
# [Iteration 9477/25137] 0.594 s/it
# prec_at_k: 0.170
# total_loss: 0.039
# Wrote snapshot to: /content/tracking_wo_bnw/output/tracktor/reid/test/ResNet_iter_9576.pth
# [*] New learning rate(s): [0.0003]
# [Iteration 9676/25137] 0.592 s/it
# prec_at_k: 0.280
# total_loss: 0.023
# [Iteration 9776/25137] 0.593 s/it
# prec_at_k: 0.290
# total_loss: 0.019
# [Iteration 9876/25137] 0.595 s/it
# prec_at_k: 0.250
# total_loss: 0.017
# Wrote snapshot to: /content/tracking_wo_bnw/output/tracktor/reid/test/ResNet_iter_9975.pth
# [*] New learning rate(s): [0.0003]
# [Iteration 10075/25137] 0.593 s/it
# prec_at_k: 0.310
# total_loss: 0.014
# [Iteration 10175/25137] 0.595 s/it
# prec_at_k: 0.330
# total_loss: 0.017
# [Iteration 10275/25137] 0.592 s/it
# prec_at_k: 0.340
# total_loss: 0.017
# Wrote snapshot to: /content/tracking_wo_bnw/output/tracktor/reid/test/ResNet_iter_10374.pth
# [*] New learning rate(s): [0.0003]
# [Iteration 10474/25137] 0.595 s/it
# prec_at_k: 0.160
# total_loss: 0.044
# [Iteration 10574/25137] 0.593 s/it
# prec_at_k: 0.220
# total_loss: 0.021
# [Iteration 10674/25137] 0.595 s/it
# prec_at_k: 0.210
# total_loss: 0.023
# Wrote snapshot to: /content/tracking_wo_bnw/output/tracktor/reid/test/ResNet_iter_10773.pth
# [*] New learning rate(s): [0.0003]
# [Iteration 10873/25137] 0.591 s/it
# prec_at_k: 0.250
# total_loss: 0.023
# [Iteration 10973/25137] 0.593 s/it
# prec_at_k: 0.230
# total_loss: 0.026
# [Iteration 11073/25137] 0.593 s/it
# prec_at_k: 0.300
# total_loss: 0.021
# Wrote snapshot to: /content/tracking_wo_bnw/output/tracktor/reid/test/ResNet_iter_11172.pth
# [*] New learning rate(s): [0.0003]
# [Iteration 11272/25137] 0.593 s/it
# prec_at_k: 0.340
# total_loss: 0.017
# [Iteration 11372/25137] 0.594 s/it
# prec_at_k: 0.280
# total_loss: 0.024
# [Iteration 11472/25137] 0.594 s/it
# prec_at_k: 0.280
# total_loss: 0.019
# Wrote snapshot to: /content/tracking_wo_bnw/output/tracktor/reid/test/ResNet_iter_11571.pth
# [*] New learning rate(s): [0.0003]
# [Iteration 11671/25137] 0.590 s/it
# prec_at_k: 0.340
# total_loss: 0.016
# [Iteration 11771/25137] 0.592 s/it
# prec_at_k: 0.290
# total_loss: 0.019
# [Iteration 11871/25137] 0.592 s/it
# prec_at_k: 0.340
# total_loss: 0.016
# Wrote snapshot to: /content/tracking_wo_bnw/output/tracktor/reid/test/ResNet_iter_11970.pth
# [*] New learning rate(s): [0.0003]
# [Iteration 12070/25137] 0.590 s/it
# prec_at_k: 0.340
# total_loss: 0.018
# [Iteration 12170/25137] 0.593 s/it
# prec_at_k: 0.300
# total_loss: 0.019
# [Iteration 12270/25137] 0.590 s/it
# prec_at_k: 0.310
# total_loss: 0.020
# Wrote snapshot to: /content/tracking_wo_bnw/output/tracktor/reid/test/ResNet_iter_12369.pth
# [*] New learning rate(s): [0.0003]
# [Iteration 12469/25137] 0.592 s/it
# prec_at_k: 0.320
# total_loss: 0.019
# [Iteration 12569/25137] 0.587 s/it
# prec_at_k: 0.380
# total_loss: 0.014
# [Iteration 12669/25137] 0.595 s/it
# prec_at_k: 0.190
# total_loss: 0.033
# Wrote snapshot to: /content/tracking_wo_bnw/output/tracktor/reid/test/ResNet_iter_12768.pth
# [*] New learning rate(s): [0.0003]
# [Iteration 12868/25137] 0.595 s/it
# prec_at_k: 0.260
# total_loss: 0.025
# [Iteration 12968/25137] 0.588 s/it
# prec_at_k: 0.360
# total_loss: 0.017
# [Iteration 13068/25137] 0.588 s/it
# prec_at_k: 0.390
# total_loss: 0.018
# Wrote snapshot to: /content/tracking_wo_bnw/output/tracktor/reid/test/ResNet_iter
# Wrote snapshot to: /content/tracking_wo_bnw/output/tracktor/reid/test/ResNet_iter_20748.pth
# [*] New learning rate(s): [5.6587597360531975e-06]
# [Iteration 20848/25137] 0.566 s/it
# prec_at_k: 0.910
# total_loss: 0.002
# [Iteration 20948/25137] 0.565 s/it
# prec_at_k: 0.900
# total_loss: 0.001
# [Iteration 21048/25137] 0.563 s/it
# prec_at_k: 0.930
# total_loss: 0.001
# Wrote snapshot to: /content/tracking_wo_bnw/output/tracktor/reid/test/ResNet_iter_21147.pth
# [*] New learning rate(s): [4.295574491359432e-06]
# [Iteration 21247/25137] 0.568 s/it
# prec_at_k: 0.850
# total_loss: 0.002
# [Iteration 21347/25137] 0.567 s/it
# prec_at_k: 0.890
# total_loss: 0.001
# [Iteration 21447/25137] 0.571 s/it
# prec_at_k: 0.820
# total_loss: 0.002
# Wrote snapshot to: /content/tracking_wo_bnw/output/tracktor/reid/test/ResNet_iter_21546.pth
# [*] New learning rate(s): [3.260778168978686e-06]
# [Iteration 21646/25137] 0.567 s/it
# prec_at_k: 0.880
# total_loss: 0.001
# [Iteration 21746/25137] 0.566 s/it
# prec_at_k: 0.860
# total_loss: 0.002
# [Iteration 21846/25137] 0.567 s/it
# prec_at_k: 0.840
# total_loss: 0.002
# Wrote snapshot to: /content/tracking_wo_bnw/output/tracktor/reid/test/ResNet_iter_21945.pth
# [*] New learning rate(s): [2.4752624564364223e-06]
# [Iteration 22045/25137] 0.568 s/it
# prec_at_k: 0.890
# total_loss: 0.001
# [Iteration 22145/25137] 0.569 s/it
# prec_at_k: 0.860
# total_loss: 0.002
# [Iteration 22245/25137] 0.566 s/it
# prec_at_k: 0.890
# total_loss: 0.001
# Wrote snapshot to: /content/tracking_wo_bnw/output/tracktor/reid/test/ResNet_iter_22344.pth
# [*] New learning rate(s): [1.878976094274667e-06]
# [Iteration 22444/25137] 0.566 s/it
# prec_at_k: 0.890
# total_loss: 0.002
# [Iteration 22544/25137] 0.568 s/it
# prec_at_k: 0.860
# total_loss: 0.001
# [Iteration 22644/25137] 0.567 s/it
# prec_at_k: 0.920
# total_loss: 0.001
# Wrote snapshot to: /content/tracking_wo_bnw/output/tracktor/reid/test/ResNet_iter_22743.pth
# [*] New learning rate(s): [1.426334065575631e-06]
# [Iteration 22843/25137] 0.570 s/it
# prec_at_k: 0.880
# total_loss: 0.002
# [Iteration 22943/25137] 0.569 s/it
# prec_at_k: 0.940
# total_loss: 0.001
# [Iteration 23043/25137] 0.569 s/it
# prec_at_k: 0.920
# total_loss: 0.001
# Wrote snapshot to: /content/tracking_wo_bnw/output/tracktor/reid/test/ResNet_iter_23142.pth
# [*] New learning rate(s): [1.082732703636045e-06]
# [Iteration 23242/25137] 0.572 s/it
# prec_at_k: 0.900
# total_loss: 0.002
# [Iteration 23342/25137] 0.574 s/it
# prec_at_k: 0.860
# total_loss: 0.002
# [Iteration 23442/25137] 0.572 s/it
# prec_at_k: 0.890
# total_loss: 0.001
# Wrote snapshot to: /content/tracking_wo_bnw/output/tracktor/reid/test/ResNet_iter_23541.pth
# [*] New learning rate(s): [8.219043040593068e-07]
# [Iteration 23641/25137] 0.570 s/it
# prec_at_k: 0.940
# total_loss: 0.001
# [Iteration 23741/25137] 0.568 s/it
# prec_at_k: 0.890
# total_loss: 0.002
# [Iteration 23841/25137] 0.567 s/it
# prec_at_k: 0.910
# total_loss: 0.002
# Wrote snapshot to: /content/tracking_wo_bnw/output/tracktor/reid/test/ResNet_iter_23940.pth
# [*] New learning rate(s): [6.239090061311086e-07]
# [Iteration 24040/25137] 0.565 s/it
# prec_at_k: 0.920
# total_loss: 0.001
# [Iteration 24140/25137] 0.563 s/it
# prec_at_k: 0.960
# total_loss: 0.001
# [Iteration 24240/25137] 0.568 s/it
# prec_at_k: 0.890
# total_loss: 0.002
# Wrote snapshot to: /content/tracking_wo_bnw/output/tracktor/reid/test/ResNet_iter_24339.pth
# [*] New learning rate(s): [4.736104264316149e-07]
# [Iteration 24439/25137] 0.563 s/it
# prec_at_k: 0.960
# total_loss: 0.000
# [Iteration 24539/25137] 0.568 s/it
# prec_at_k: 0.860
# total_loss: 0.002
# [Iteration 24639/25137] 0.569 s/it
# prec_at_k: 0.900
# total_loss: 0.001
# Wrote snapshot to: /content/tracking_wo_bnw/output/tracktor/reid/test/ResNet_iter_24738.pth
# [*] New learning rate(s): [3.5951850962318053e-07]
# [Iteration 24838/25137] 0.565 s/it
# prec_at_k: 0.950
# total_loss: 0.001
# [Iteration 24938/25137] 0.569 s/it
# prec_at_k: 0.930
# total_loss: 0.001
# [Iteration 25038/25137] 0.570 s/it
# prec_at_k: 0.860
# total_loss: 0.001
# Wrote snapshot to: /content/tracking_wo_bnw/output/tracktor/reid/test/ResNet_iter_25137.pth
# FINISH.
# INFO - train_reid - Completed after 4:23:49

# %%
# %ls output/tracktor/reid/test
# Out:
# ResNet_iter_10374.pth  ResNet_iter_18354.pth  ResNet_iter_3591.pth
# ResNet_iter_10773.pth  ResNet_iter_18753.pth  ResNet_iter_3990.pth
# ResNet_iter_11172.pth  ResNet_iter_19152.pth  ResNet_iter_399.pth
# ResNet_iter_11571.pth  ResNet_iter_19551.pth  ResNet_iter_4389.pth
# ResNet_iter_11970.pth  ResNet_iter_19950.pth  ResNet_iter_4788.pth
# ResNet_iter_1197.pth   ResNet_iter_1995.pth   ResNet_iter_5187.pth
# ResNet_iter_12369.pth  ResNet_iter_20349.pth  ResNet_iter_5586.pth
# ResNet_iter_12768.pth  ResNet_iter_20748.pth  ResNet_iter_5985.pth
# ResNet_iter_13167.pth  ResNet_iter_21147.pth  ResNet_iter_6384.pth
# ResNet_iter_13566.pth  ResNet_iter_21546.pth  ResNet_iter_6783.pth
# ResNet_iter_13965.pth  ResNet_iter_21945.pth  ResNet_iter_7182.pth
# ResNet_iter_14364.pth  ResNet_iter_22344.pth  ResNet_iter_7581.pth
# ResNet_iter_14763.pth  ResNet_iter_22743.pth  ResNet_iter_7980.pth
# ResNet_iter_15162.pth  ResNet_iter_23142.pth  ResNet_iter_798.pth
# ResNet_iter_15561.pth  ResNet_iter_23541.pth  ResNet_iter_8379.pth
# ResNet_iter_15960.pth  ResNet_iter_23940.pth  ResNet_iter_8778.pth
# ResNet_iter_1596.pth   ResNet_iter_2394.pth   ResNet_iter_9177.pth
# ResNet_iter_16359.pth  ResNet_iter_24339.pth  ResNet_iter_9576.pth
# ResNet_iter_16758.pth  ResNet_iter_24738.pth  ResNet_iter_9975.pth
# ResNet_iter_17157.pth  ResNet_iter_25137.pth  sacred_config.yaml
# ResNet_iter_17556.pth  ResNet_iter_2793.pth
# ResNet_iter_17955.pth  ResNet_iter_3192.pth

# %% [markdown]
# zip output directory (optional)

# %%
! zip -r output.zip output

# %%
# !du -h output.zip
# Out:
# 5.9G	output.zip

# %% [markdown]
# copy zip file to google drive

# %%
! cp output.zip '../gdrive/My Drive/'

# %%
! du -h '../gdrive/My Drive/output.zip'
# Out:
# 5.9G	../gdrive/My Drive/output.zip
